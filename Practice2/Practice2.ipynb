# %%
import os
import torch
from torch import nn
import torch.nn.functional as F
from torchvision import transforms
from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
import lightning.pytorch as pl
from lightning.pytorch.callbacks.early_stopping import EarlyStopping
from lightning.pytorch.callbacks import ModelSummary
from lightning.pytorch.callbacks import ModelCheckpoint

# %%
class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.l1 = nn.Sequential(nn.Linear(28 * 28, 64), nn.ReLU(), nn.Linear(64, 3))

    def forward(self, x):
        return self.l1(x)


class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.l1 = nn.Sequential(nn.Linear(3, 64), nn.ReLU(), nn.Linear(64, 28 * 28))

    def forward(self, x):
        return self.l1(x)

# %%
class LitAutoEncoder(pl.LightningModule):
    def __init__(self, encoder, decoder):
        super().__init__()
        self.save_hyperparameters()
        self.encoder = encoder
        self.decoder = decoder

    def training_step(self, batch, batch_idx):
        # training_step defines the train loop.
        x, y = batch
        x = x.view(x.size(0), -1)
        z = self.encoder(x)
        x_hat = self.decoder(z)
        loss = F.mse_loss(x_hat, x)
        return loss
    
    def test_step(self, batch, batch_idx):
        # this is the test loop
        x, y = batch
        x = x.view(x.size(0), -1)
        z = self.encoder(x)
        x_hat = self.decoder(z)
        test_loss = F.mse_loss(x_hat, x)
        self.log("test_loss", test_loss)
        
    def validation_step(self, batch, batch_idx):
        # this is the validation loop
        x, y = batch
        x = x.view(x.size(0), -1)
        z = self.encoder(x)
        x_hat = self.decoder(z)
        val_loss = F.mse_loss(x_hat, x)
        self.log("val_loss", val_loss)

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=1e-3)
        return optimizer

# %%
# Load data sets
transform = transforms.ToTensor()
train_set = MNIST(root="MNIST", download=True, train=True, transform=transform)
test_set = MNIST(root="MNIST", download=True, train=False, transform=transform)

# use 20% of training data for validation
train_set_size = int(len(train_set) * 0.8)
valid_set_size = len(train_set) - train_set_size

# split the train set into two
seed = torch.Generator().manual_seed(42)
train_set, valid_set = torch.utils.data.random_split(train_set, [train_set_size, valid_set_size], generator=seed)

# %%
# model
autoencoder = LitAutoEncoder(Encoder(), Decoder())

train_loader = DataLoader(train_set)
valid_loader = DataLoader(valid_set)

early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=0.02, patience=3, verbose=False, mode="min")
checkpoint_callback = ModelCheckpoint(dirpath="checkpoints", 
                                      save_top_k=2, 
                                      monitor="val_loss",
                                      mode="min",
                                      filename="sample-mnist-{epoch:02d}-{val_loss:.2f}")
model_summary = ModelSummary(max_depth=-1)
# train model
trainer = pl.Trainer(
    default_root_dir="logs/", 
    callbacks=[early_stop_callback, checkpoint_callback, model_summary], 
    profiler="simple", 
    max_epochs=1,
    precision='16-mixed') # 32, 64
trainer.fit(model=autoencoder, train_dataloaders=train_loader, val_dataloaders=valid_loader)
# Out:
# C:\Users\alexa\miniconda3\envs\classes\lib\site-packages\lightning\pytorch\utilities\parsing.py:196: UserWarning: Attribute 'encoder' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['encoder'])`.
#   rank_zero_warn(
# C:\Users\alexa\miniconda3\envs\classes\lib\site-packages\lightning\pytorch\utilities\parsing.py:196: UserWarning: Attribute 'decoder' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['decoder'])`.
#   rank_zero_warn(
# Using 16bit Automatic Mixed Precision (AMP)
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA GeForce RTX 3050 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Missing logger folder: logs\lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type       | Params
# --------------------------------------------
# 0 | encoder      | Encoder    | 50.4 K
# 1 | encoder.l1   | Sequential | 50.4 K
# 2 | encoder.l1.0 | Linear     | 50.2 K
# 3 | encoder.l1.1 | ReLU       | 0
# 4 | encoder.l1.2 | Linear     | 195
# 5 | decoder      | Decoder    | 51.2 K
# 6 | decoder.l1   | Sequential | 51.2 K
# 7 | decoder.l1.0 | Linear     | 256
# 8 | decoder.l1.1 | ReLU       | 0
# 9 | decoder.l1.2 | Linear     | 51.0 K
# --------------------------------------------
# 101 K     Trainable params
# 0         Non-trainable params
# 101 K     Total params
# 0.407     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# C:\Users\alexa\miniconda3\envs\classes\lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:432: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# C:\Users\alexa\miniconda3\envs\classes\lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:432: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# `Trainer.fit` stopped: `max_epochs=1` reached.
# FIT Profiler Report
#
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                               	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                	|  -              	|  2208141        	|  252.76         	|  100 %          	|
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                   	|  247.42         	|  1              	|  247.42         	|  97.886         	|
# |  run_training_batch                                                                                                                                                   	|  0.0027805      	|  48000          	|  133.47         	|  52.802         	|
# |  [LightningModule]LitAutoEncoder.optimizer_step                                                                                                                       	|  0.002725       	|  48000          	|  130.8          	|  51.748         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                              	|  0.00088685     	|  48000          	|  42.569         	|  16.841         	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                         	|  0.00076275     	|  48000          	|  36.612         	|  14.485         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                         	|  0.00066146     	|  48000          	|  31.75          	|  12.561         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                           	|  0.00062325     	|  48000          	|  29.916         	|  11.835         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                       	|  0.00076379     	|  12002          	|  9.167          	|  3.6267         	|
# |  [_EvaluationLoop].val_next                                                                                                                                           	|  0.00052504     	|  12003          	|  6.302          	|  2.4932         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                       	|  7.7964e-05     	|  60002          	|  4.678          	|  1.8507         	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                    	|  0.00034061     	|  12002          	|  4.088          	|  1.6173         	|
# |  [LightningModule]LitAutoEncoder.transfer_batch_to_device                                                                                                             	|  5.1915e-05     	|  60002          	|  3.115          	|  1.2324         	|
# |  [LightningModule]LitAutoEncoder.optimizer_zero_grad                                                                                                                  	|  5.2333e-05     	|  48000          	|  2.512          	|  0.99381        	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_end       	|  2.1875e-05     	|  48000          	|  1.05           	|  0.41541        	|
# |  [LightningModule]LitAutoEncoder.configure_gradient_clipping                                                                                                          	|  2.1208e-05     	|  48000          	|  1.018          	|  0.40275        	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_start                                                                                   	|  5.2083e-06     	|  48000          	|  0.25           	|  0.098906       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_zero_grad                                                                                    	|  2.9583e-06     	|  48000          	|  0.142          	|  0.056179       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_backward                                                                                     	|  2.9375e-06     	|  48000          	|  0.141          	|  0.055783       	|
# |  [LightningModule]LitAutoEncoder.on_before_batch_transfer                                                                                                             	|  2.0833e-06     	|  60002          	|  0.125          	|  0.049453       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_after_backward                                                                                      	|  2.2917e-06     	|  48000          	|  0.11           	|  0.043519       	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                            	|  2.2708e-06     	|  48000          	|  0.109          	|  0.043123       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_optimizer_step                                                                               	|  2.2708e-06     	|  48000          	|  0.109          	|  0.043123       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_after_backward        	|  2e-06          	|  48000          	|  0.096          	|  0.03798        	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                      	|  1.9583e-06     	|  48000          	|  0.094          	|  0.037189       	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                  	|  1.9583e-06     	|  48000          	|  0.094          	|  0.037189       	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                       	|  1.9375e-06     	|  48000          	|  0.093          	|  0.036793       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_end                                                                                     	|  1.9167e-06     	|  48000          	|  0.092          	|  0.036397       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_zero_grad      	|  1.625e-06      	|  48000          	|  0.078          	|  0.030859       	|
# |  [LightningModule]LitAutoEncoder.on_before_optimizer_step                                                                                                             	|  1.3333e-06     	|  48000          	|  0.064          	|  0.02532        	|
# |  [LightningModule]LitAutoEncoder.on_before_backward                                                                                                                   	|  1.3125e-06     	|  48000          	|  0.063          	|  0.024924       	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                            	|  1.2917e-06     	|  48000          	|  0.062          	|  0.024529       	|
# |  [LightningModule]LitAutoEncoder.on_before_zero_grad                                                                                                                  	|  1.2917e-06     	|  48000          	|  0.062          	|  0.024529       	|
# |  [LightningModule]LitAutoEncoder.on_train_batch_end                                                                                                                   	|  1.2917e-06     	|  48000          	|  0.062          	|  0.024529       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_backward       	|  1e-06          	|  48000          	|  0.048          	|  0.01899        	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                        	|  0.0235         	|  2              	|  0.047          	|  0.018594       	|
# |  [LightningModule]LitAutoEncoder.on_after_batch_transfer                                                                                                              	|  7.8331e-07     	|  60002          	|  0.047          	|  0.018594       	|
# |  [LightningModule]LitAutoEncoder.on_train_batch_start                                                                                                                 	|  9.5833e-07     	|  48000          	|  0.046          	|  0.018199       	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                         	|  9.5833e-07     	|  48000          	|  0.046          	|  0.018199       	|
# |  [LightningModule]LitAutoEncoder.on_after_backward                                                                                                                    	|  9.5833e-07     	|  48000          	|  0.046          	|  0.018199       	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                        	|  9.375e-07      	|  48000          	|  0.045          	|  0.017803       	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                          	|  6.6667e-07     	|  48000          	|  0.032          	|  0.01266        	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_start     	|  6.6667e-07     	|  48000          	|  0.032          	|  0.01266        	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                             	|  6.6667e-07     	|  48000          	|  0.032          	|  0.01266        	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                          	|  6.4583e-07     	|  48000          	|  0.031          	|  0.012264       	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                           	|  6.4583e-07     	|  48000          	|  0.031          	|  0.012264       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_end  	|  2.5829e-06     	|  12002          	|  0.031          	|  0.012264       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_end                                                                                	|  2.4996e-06     	|  12002          	|  0.03           	|  0.011869       	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                      	|  0.016          	|  1              	|  0.016          	|  0.00633        	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                     	|  1.3331e-06     	|  12002          	|  0.016          	|  0.00633        	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                       	|  1.3331e-06     	|  12002          	|  0.016          	|  0.00633        	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                   	|  3.3333e-07     	|  48000          	|  0.016          	|  0.00633        	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_end                                                                                     	|  0.016          	|  1              	|  0.016          	|  0.00633        	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                             	|  0.016          	|  1              	|  0.016          	|  0.00633        	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_optimizer_step 	|  3.3333e-07     	|  48000          	|  0.016          	|  0.00633        	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_start	|  1.2498e-06     	|  12002          	|  0.015          	|  0.0059344      	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                  	|  1.2498e-06     	|  12002          	|  0.015          	|  0.0059344      	|
# |  [LightningModule]LitAutoEncoder.on_validation_batch_start                                                                                                            	|  1.2498e-06     	|  12002          	|  0.015          	|  0.0059344      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_end       	|  0.015          	|  1              	|  0.015          	|  0.0059344      	|
# |  [LightningModule]LitAutoEncoder.configure_callbacks                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.prepare_data                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.setup                                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                      	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup                    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.setup                                                                                                                                	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.configure_sharded_model                                                                                                              	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.configure_optimizers                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_start                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start             	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_fit_start                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_start                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_start    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_model_eval                                                                                                             	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_start                                                                                    	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                           	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_start      	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_start                                                                                                                  	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                                   	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_start                                                                              	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                     	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                                  	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_start	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_epoch_start                                                                                                            	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_start                                                                              	|  0.0            	|  12002          	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_batch_end                                                                                                              	|  0.0            	|  12002          	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_end                                                                                	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                       	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                    	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_end  	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_epoch_end                                                                                                              	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_end                                                                                      	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                             	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                          	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_end        	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_end                                                                                                                    	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                     	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_model_train                                                                                                            	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_end                                                                                    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_end      	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_start                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                                	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_start                                                                                                                       	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_start                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                       	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start     	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_epoch_start                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_epoch_end                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_save_checkpoint                                                                                     	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint       	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_save_checkpoint                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_end                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end             	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_end                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_end                                                                                             	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_fit_end                                                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown                                                                                               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.teardown                                                                                                                                      	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.teardown                                                                                                                             	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# test the model
trainer.test(autoencoder, dataloaders=DataLoader(test_set))
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3050 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# C:\Users\alexa\miniconda3\envs\classes\lib\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:432: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_loss           0.0415462926030159
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# TEST Profiler Report
#
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                               	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                                	|  -              	|  2368178        	|  380.09         	|  100 %          	|
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                                   	|  247.42         	|  1              	|  247.42         	|  65.095         	|
# |  run_training_batch                                                                                                                                                   	|  0.0027805      	|  48000          	|  133.47         	|  35.114         	|
# |  [LightningModule]LitAutoEncoder.optimizer_step                                                                                                                       	|  0.002725       	|  48000          	|  130.8          	|  34.413         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                              	|  0.00088685     	|  48000          	|  42.569         	|  11.2           	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                         	|  0.00076275     	|  48000          	|  36.612         	|  9.6324         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                         	|  0.00066146     	|  48000          	|  31.75          	|  8.3532         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                           	|  0.00062325     	|  48000          	|  29.916         	|  7.8707         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                       	|  0.00076379     	|  12002          	|  9.167          	|  2.4118         	|
# |  [Strategy]SingleDeviceStrategy.test_step                                                                                                                             	|  0.0006637      	|  10000          	|  6.637          	|  1.7462         	|
# |  [_EvaluationLoop].val_next                                                                                                                                           	|  0.00052504     	|  12003          	|  6.302          	|  1.658          	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                       	|  8.1683e-05     	|  70002          	|  5.718          	|  1.5044         	|
# |  [_EvaluationLoop].test_next                                                                                                                                          	|  0.0005139      	|  10000          	|  5.139          	|  1.352          	|
# |  [Callback]TQDMProgressBar.on_test_batch_end                                                                                                                          	|  0.0004339      	|  10000          	|  4.339          	|  1.1416         	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                                    	|  0.00034061     	|  12002          	|  4.088          	|  1.0755         	|
# |  [LightningModule]LitAutoEncoder.transfer_batch_to_device                                                                                                             	|  5.5127e-05     	|  70002          	|  3.859          	|  1.0153         	|
# |  [LightningModule]LitAutoEncoder.optimizer_zero_grad                                                                                                                  	|  5.2333e-05     	|  48000          	|  2.512          	|  0.66089        	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_end       	|  2.1875e-05     	|  48000          	|  1.05           	|  0.27625        	|
# |  [LightningModule]LitAutoEncoder.configure_gradient_clipping                                                                                                          	|  2.1208e-05     	|  48000          	|  1.018          	|  0.26783        	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_start                                                                                   	|  5.2083e-06     	|  48000          	|  0.25           	|  0.065773       	|
# |  [LightningModule]LitAutoEncoder.on_before_batch_transfer                                                                                                             	|  2.2428e-06     	|  70002          	|  0.157          	|  0.041306       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_zero_grad                                                                                    	|  2.9583e-06     	|  48000          	|  0.142          	|  0.037359       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_backward                                                                                     	|  2.9375e-06     	|  48000          	|  0.141          	|  0.037096       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_after_backward                                                                                      	|  2.2917e-06     	|  48000          	|  0.11           	|  0.02894        	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                            	|  2.2708e-06     	|  48000          	|  0.109          	|  0.028677       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_optimizer_step                                                                               	|  2.2708e-06     	|  48000          	|  0.109          	|  0.028677       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_after_backward        	|  2e-06          	|  48000          	|  0.096          	|  0.025257       	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                      	|  1.9583e-06     	|  48000          	|  0.094          	|  0.024731       	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                                  	|  1.9583e-06     	|  48000          	|  0.094          	|  0.024731       	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                       	|  1.9375e-06     	|  48000          	|  0.093          	|  0.024468       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_end                                                                                     	|  1.9167e-06     	|  48000          	|  0.092          	|  0.024205       	|
# |  [LightningModule]LitAutoEncoder.on_after_batch_transfer                                                                                                              	|  1.1285e-06     	|  70002          	|  0.079          	|  0.020784       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_zero_grad      	|  1.625e-06      	|  48000          	|  0.078          	|  0.020521       	|
# |  [LightningModule]LitAutoEncoder.on_before_optimizer_step                                                                                                             	|  1.3333e-06     	|  48000          	|  0.064          	|  0.016838       	|
# |  [LightningModule]LitAutoEncoder.on_before_backward                                                                                                                   	|  1.3125e-06     	|  48000          	|  0.063          	|  0.016575       	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                            	|  1.2917e-06     	|  48000          	|  0.062          	|  0.016312       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_end        	|  6.2e-06        	|  10000          	|  0.062          	|  0.016312       	|
# |  [LightningModule]LitAutoEncoder.on_before_zero_grad                                                                                                                  	|  1.2917e-06     	|  48000          	|  0.062          	|  0.016312       	|
# |  [LightningModule]LitAutoEncoder.on_train_batch_end                                                                                                                   	|  1.2917e-06     	|  48000          	|  0.062          	|  0.016312       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_backward       	|  1e-06          	|  48000          	|  0.048          	|  0.012628       	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                        	|  0.0235         	|  2              	|  0.047          	|  0.012365       	|
# |  [LightningModule]LitAutoEncoder.on_train_batch_start                                                                                                                 	|  9.5833e-07     	|  48000          	|  0.046          	|  0.012102       	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                         	|  9.5833e-07     	|  48000          	|  0.046          	|  0.012102       	|
# |  [LightningModule]LitAutoEncoder.on_after_backward                                                                                                                    	|  9.5833e-07     	|  48000          	|  0.046          	|  0.012102       	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                        	|  9.375e-07      	|  48000          	|  0.045          	|  0.011839       	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                          	|  6.6667e-07     	|  48000          	|  0.032          	|  0.008419       	|
# |  [Callback]ModelSummary.on_test_batch_start                                                                                                                           	|  3.2e-06        	|  10000          	|  0.032          	|  0.008419       	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_start     	|  6.6667e-07     	|  48000          	|  0.032          	|  0.008419       	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                             	|  6.6667e-07     	|  48000          	|  0.032          	|  0.008419       	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                          	|  6.4583e-07     	|  48000          	|  0.031          	|  0.0081559      	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                           	|  6.4583e-07     	|  48000          	|  0.031          	|  0.0081559      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_end  	|  2.5829e-06     	|  12002          	|  0.031          	|  0.0081559      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_end                                                                                	|  2.4996e-06     	|  12002          	|  0.03           	|  0.0078928      	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                      	|  0.016          	|  1              	|  0.016          	|  0.0042095      	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                                     	|  1.3331e-06     	|  12002          	|  0.016          	|  0.0042095      	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                       	|  1.3331e-06     	|  12002          	|  0.016          	|  0.0042095      	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                                   	|  3.3333e-07     	|  48000          	|  0.016          	|  0.0042095      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_end                                                                                     	|  0.016          	|  1              	|  0.016          	|  0.0042095      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_batch_start                                                                                    	|  1.6e-06        	|  10000          	|  0.016          	|  0.0042095      	|
# |  [Callback]ModelSummary.on_test_batch_end                                                                                                                             	|  1.6e-06        	|  10000          	|  0.016          	|  0.0042095      	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                             	|  0.016          	|  1              	|  0.016          	|  0.0042095      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_optimizer_step 	|  3.3333e-07     	|  48000          	|  0.016          	|  0.0042095      	|
# |  [LightningModule]LitAutoEncoder.on_test_batch_end                                                                                                                    	|  1.6e-06        	|  10000          	|  0.016          	|  0.0042095      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_start	|  1.2498e-06     	|  12002          	|  0.015          	|  0.0039464      	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                                  	|  1.2498e-06     	|  12002          	|  0.015          	|  0.0039464      	|
# |  [LightningModule]LitAutoEncoder.on_validation_batch_start                                                                                                            	|  1.2498e-06     	|  12002          	|  0.015          	|  0.0039464      	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_end       	|  0.015          	|  1              	|  0.015          	|  0.0039464      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_batch_end                                                                                      	|  1.5e-06        	|  10000          	|  0.015          	|  0.0039464      	|
# |  [LightningModule]LitAutoEncoder.configure_callbacks                                                                                                                  	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.prepare_data                                                                                                                         	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup                                                                                                  	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.setup                                                                                                                                         	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                      	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup                    	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.setup                                                                                                                                	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.configure_sharded_model                                                                                                              	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.configure_optimizers                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_start                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start             	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_fit_start                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_start                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_start    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_model_eval                                                                                                             	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_start                                                                                    	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                           	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_start      	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_start                                                                                                                  	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                                   	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_start                                                                              	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                                     	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                                  	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_start	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_epoch_start                                                                                                            	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_start                                                                              	|  0.0            	|  12002          	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_batch_end                                                                                                              	|  0.0            	|  12002          	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_end                                                                                	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                       	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                                    	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_end  	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_epoch_end                                                                                                              	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_end                                                                                      	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                             	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                          	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_end        	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_end                                                                                                                    	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                                     	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_validation_model_train                                                                                                            	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_end                                                                                    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_end      	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_start                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                                	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_start                                                                                                                       	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_start                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                       	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start     	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_epoch_start                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_epoch_end                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_save_checkpoint                                                                                     	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint       	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_save_checkpoint                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_end                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end             	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_train_end                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_end                                                                                             	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                                    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end               	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_fit_end                                                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown                                                                                               	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.teardown                                                                                                                                      	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                                   	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                 	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.teardown                                                                                                                             	|  0.0            	|  2              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_test_model_eval                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_start                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_test_start                                                                                                                                 	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_test_start                                                                                                                              	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_start            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_test_start                                                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_test_start                                                                                                                         	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_epoch_start                                                                                    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_test_epoch_start                                                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_test_epoch_start                                                                                                                        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_start      	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_test_epoch_start                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_test_batch_start                                                                                                                        	|  0.0            	|  10000          	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_start      	|  0.0            	|  10000          	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_test_batch_start                                                                                                                  	|  0.0            	|  10000          	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_epoch_end                                                                                      	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_test_epoch_end                                                                                                                             	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_test_epoch_end                                                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_end        	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_test_epoch_end                                                                                                                    	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_end                                                                                            	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelSummary.on_test_end                                                                                                                                   	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]TQDMProgressBar.on_test_end                                                                                                                                	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Callback]ModelCheckpoint{'monitor': 'val_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_end              	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_test_end                                                                                                                          	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [Strategy]SingleDeviceStrategy.on_test_end                                                                                                                           	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# |  [LightningModule]LitAutoEncoder.on_test_model_train                                                                                                                  	|  0.0            	|  1              	|  0.0            	|  0.0            	|
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [{'test_loss': 0.0415462926030159}]
